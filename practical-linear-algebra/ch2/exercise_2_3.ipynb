# %%
import numpy as np

# %%
def unit_vector(vector: np.ndarray) -> np.ndarray:
    return vector / np.linalg.norm(vector)

# %%
# we'd expect this to be ~1
np.linalg.norm(unit_vector(np.array([2, 1])))
# Out:
# np.float64(0.9999999999999999)
